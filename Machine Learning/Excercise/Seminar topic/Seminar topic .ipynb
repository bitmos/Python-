# %%
import pandas as pd
df=pd.read_excel("Seminar_Topic_Allotment.xlsx",header=4,index_col=0)
df.head()
# Out:
#    PUCS001    ABIGAIL          LOCATION BASED SERVICE  Unnamed: 4
# 1
# 2  PUCS002  ALEXANDRA       COMPUTATIONAL PHOTOGRAPHY         NaN
# 3  PUCS003     ALISON  BLUETOOTH BASED SENSOR NETWORK         NaN
# 4  PUCS004     AMANDA                ROVER TECHNOLOGY         NaN
# 5  PUCS006     AMELIA                HUMAN ID IMPLANT         NaN
# 6  PUCS007        AMY                         WISENET         NaN

# %%
df.describe()
# Out:
#         PUCS001 ABIGAIL LOCATION BASED SERVICE
# count        85      85                     85
# unique       85      85                     83
# top     PUCS023   SARAH            WINDOWS DNA
# freq          1       1                      2

# %%
df.drop(columns=['Unnamed: 4'],inplace=True)
df
# Out:
#     PUCS001    ABIGAIL                             LOCATION BASED SERVICE
# 1
# 2   PUCS002  ALEXANDRA                          COMPUTATIONAL PHOTOGRAPHY
# 3   PUCS003     ALISON                     BLUETOOTH BASED SENSOR NETWORK
# 4   PUCS004     AMANDA                                   ROVER TECHNOLOGY
# 5   PUCS006     AMELIA                                   HUMAN ID IMPLANT
# 6   PUCS007        AMY                                            WISENET
# ..      ...        ...                                                ...
# 82  PUCS085   VIRGINIA  EPICS - ELECTROMECHANICAL HUMAN MACHINE INTERA...
# 83  PUCS086      WANDA   HEART FAILURE ALERT SYSTEM USING RFID TECHNOLOGY
# 84  PUCS087      WENDY                                 IMAGE THRESHOLDING
# 85  PUCS088     YVONNE                                              FUTEX
# 86  PUCS089        ZOE                                IP VERSION 6 - IPV6
#
# [85 rows x 3 columns]

# %%
a=[]
for j in range(85):
    a.append(df.sample(n=5))
    
df['NOTES']=a
df
# Out:
#     PUCS001    ABIGAIL                             LOCATION BASED SERVICE  \
# 1
# 2   PUCS002  ALEXANDRA                          COMPUTATIONAL PHOTOGRAPHY
# 3   PUCS003     ALISON                     BLUETOOTH BASED SENSOR NETWORK
# 4   PUCS004     AMANDA                                   ROVER TECHNOLOGY
# 5   PUCS006     AMELIA                                   HUMAN ID IMPLANT
# 6   PUCS007        AMY                                            WISENET
# ..      ...        ...                                                ...
# 82  PUCS085   VIRGINIA  EPICS - ELECTROMECHANICAL HUMAN MACHINE INTERA...
# 83  PUCS086      WANDA   HEART FAILURE ALERT SYSTEM USING RFID TECHNOLOGY
# 84  PUCS087      WENDY                                 IMAGE THRESHOLDING
# 85  PUCS088     YVONNE                                              FUTEX
# 86  PUCS089        ZOE                                IP VERSION 6 - IPV6
#
#                                                 NOTES
# 1
# ...

# %%
df2=a
df2.drop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-9ed745dae12c> in <module>
#       1 df2=a
# ----> 2 df2.drop(index)
#
# AttributeError: 'list' object has no attribute 'drop'

# %%
df.to_excel('alloted.xlsx')
