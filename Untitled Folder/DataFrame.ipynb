# %%
import pandas as p
df =p.read_excel("Bangalore_medical_oxygen.xlsx")
df
# Out:
#                            Company Name   Contact Person Name  \
# 0                Amogh Gases Pvt. Ltd.          R Mohan Kumar
# 1               Bhuruka Gases Pvt. Ltd.                Mahesh
# 2                          Eureka Gases             Manjunath
# 3                  Galaxy Air Products           R Tothumuthu
# 4   Pai Industrial And \nMedical Gases               Ravi Pai
# 5                    Praxair Pvt. Ltd.            R C Kaushik
# 6                          Southern Gas                 S Pai
# 7          Spec & Cal Gases \nPvt. Ltd.           K Manoharan
# 8                Universal Air Products            RajaShehal
# 9             Universal Air \nProducts   Subhashish Guha Roy
# 10  Peenya Industrial \nGases Pvt. Ltd.          Prem Krishna
#
#               Contact Number         City  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                 9448483854    Bengaluru         NaN         NaN         NaN
# ...

# %%
df.shape
# Out:
# (11, 26)

# %%
df.head()
# Out:
#                           Company Name Contact Person Name  \
# 0               Amogh Gases Pvt. Ltd.        R Mohan Kumar
# 1              Bhuruka Gases Pvt. Ltd.              Mahesh
# 2                         Eureka Gases           Manjunath
# 3                 Galaxy Air Products         R Tothumuthu
# 4  Pai Industrial And \nMedical Gases             Ravi Pai
#
#              Contact Number       City  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0                9448483854  Bengaluru         NaN         NaN         NaN
# 1                7760976502  Bangalore         NaN         NaN         NaN
# 2  9035588758 \n9535509423   Bangalore         NaN         NaN         NaN
# 3  9448821347 \n8867715015   Bangalore         NaN         NaN         NaN
# 4  9845063166 \n9152108947   Bangalore         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  \
# 0         NaN         NaN         NaN  ...          NaN          NaN
# ...

# %%
df.columns
# Out:
# Index(['Company Name', 'Contact Person Name', 'Contact Number', 'City',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
student_info = {'Name':['Neha','Rakshith','Shravan','Prarthana','Rohit'],
'USN':['1JT19CS055','1JT19CS086','1JT19CS069','1JT19CS063','1JT19CS074'],
'Marks':[92,9,88,86,96],
'Result':['pass','fail','pass','pass','pass']}
df =p.DataFrame(student_info)
df
# Out:
#         Name         USN  Marks Result
# 0       Neha  1JT19CS055     92   pass
# 1   Rakshith  1JT19CS086      9   fail
# 2    Shravan  1JT19CS069     88   pass
# 3  Prarthana  1JT19CS063     86   pass
# 4      Rohit  1JT19CS074     96   pass

# %%
df.shape
# Out:
# (5, 4)

# %%
df['Marks'].max()
# Out:
# 96

# %%
df.describe()
# Out:
#            Marks
# count   5.000000
# mean   74.200000
# std    36.649693
# min     9.000000
# 25%    86.000000
# 50%    88.000000
# 75%    92.000000
# max    96.000000

# %%
df[df.Marks>32]
# Out:
#         Name         USN  Marks Result
# 0       Neha  1JT19CS055     92   pass
# 2    Shravan  1JT19CS069     88   pass
# 3  Prarthana  1JT19CS063     86   pass
# 4      Rohit  1JT19CS074     96   pass

# %%
df[df.Marks==df.Marks.max()]
# Out:
#     Name         USN  Marks Result
# 4  Rohit  1JT19CS074     96   pass

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.set_index('Name',inplace=True)

# %%
df.loc['Rohit']
# Out:
# USN       1JT19CS074
# Marks             96
# Result          pass
# Name: Rohit, dtype: object
