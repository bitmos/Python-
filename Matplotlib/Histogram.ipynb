# %%
import matplotlib.pyplot as plt
# %matplotlib inline
a=[67,87,99,20,42,78,65,78,87,59]
b=[75,68,34,59,40,38,90,39,47,78]
c=[95,96,49,49,78,66,85,25,45,36]
plt.xlabel('Sections')
plt.ylabel('No of students')
plt.title('CSE Marks for SEM I')
plt.hist([a,b,c],bins=[0,35,50,70,85,100],
         rwidth=.9,label=['Sec-A','Sec-B','Sec-C'],
         color=['green','red','blue'])
plt.legend()
plt.savefig('firstfig.png')
